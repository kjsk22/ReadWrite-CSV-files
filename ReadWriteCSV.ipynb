# %%
import pandas as pd
df = pd.read_csv('Fish.csv',skiprows=1)
df
# Out:
#      Species Weight(Grams)  Vertical Length(Cm) Diagonal Length(Cm)  \
# 0      Bream           242                 23.2                25.4
# 1      Roach           272                 25.0                  27
# 2  Whitefish           800                 33.7                 N\A
# 3     Parkki           N\A                -22.0                  25
# 4      Perch            ##                 40.2                43.5
# 5       Pike           200                 30.0                32.3
# 6      Smelt          19.7                 13.2                14.3
#
#   Cross Length(Cm)
# 0               30
# 1             30.6
# 2             39.6
# 3               28
# 4               46
# 5              N\A
# 6              N\A

# %%
df = pd.read_csv('Fish.csv',header=2)
df
# Out:
#        Bream   242  23.2  25.4    30
# 0      Roach   272  25.0    27  30.6
# 1  Whitefish   800  33.7   N\A  39.6
# 2     Parkki   N\A -22.0    25    28
# 3      Perch    ##  40.2  43.5    46
# 4       Pike   200  30.0  32.3   N\A
# 5      Smelt  19.7  13.2  14.3   N\A

# %%
df = pd.read_csv('Fish.csv',header=None)
df
# Out:
#            0     1     2     3     4
# 0      Bream   242  23.2  25.4    30
# 1      Roach   272  25.0    27  30.6
# 2  Whitefish   800  33.7   N\A  39.6
# 3     Parkki   N\A -22.0    25    28
# 4      Perch    ##  40.2  43.5    46
# 5       Pike   200  30.0  32.3   N\A
# 6      Smelt  19.7  13.2  14.3   N\A

# %%
df = pd.read_csv('Fish.csv',nrows=2)
df
# Out:
#   Species  Weight(Grams)  Vertical Length(Cm)  Diagonal Length(Cm)  \
# 0   Bream            242                 23.2                 25.4
# 1   Roach            272                 25.0                 27.0
#
#    Cross Length(Cm)
# 0              30.0
# 1              30.6

# %%
df = pd.read_csv('Fish.csv',na_values=['N\A','##'])
df
# Out:
#      Species  Weight(Grams)  Vertical Length(Cm)  Diagonal Length(Cm)  \
# 0      Bream          242.0                 23.2                 25.4
# 1      Roach          272.0                 25.0                 27.0
# 2  Whitefish          800.0                 33.7                  NaN
# 3     Parkki            NaN                -22.0                 25.0
# 4      Perch            NaN                 40.2                 43.5
# 5       Pike          200.0                 30.0                 32.3
# 6      Smelt           19.7                 13.2                 14.3
#
#    Cross Length(Cm)
# 0              30.0
# 1              30.6
# 2              39.6
# 3              28.0
# 4              46.0
# 5               NaN
# 6               NaN

# %%
df = pd.read_csv('Fish.csv',na_values={'Weight(Grams)':['N\A','##'],'Vertical Length(Cm)':-22,'Diagonal Length(Cm)':'N\A'})
df
# Out:
#      Species  Weight(Grams)  Vertical Length(Cm)  Diagonal Length(Cm)  \
# 0      Bream          242.0                 23.2                 25.4
# 1      Roach          272.0                 25.0                 27.0
# 2  Whitefish          800.0                 33.7                  NaN
# 3     Parkki            NaN                  NaN                 25.0
# 4      Perch            NaN                 40.2                 43.5
# 5       Pike          200.0                 30.0                 32.3
# 6      Smelt           19.7                 13.2                 14.3
#
#   Cross Length(Cm)
# 0               30
# 1             30.6
# 2             39.6
# 3               28
# 4               46
# 5              N\A
# 6              N\A

# %%
df.to_csv('newcsvfile.csv',index=False)

# %%
df.to_csv('newcsvfile.csv',index=False, header=False)

# %%
df.to_csv('newcsvfile.csv',index=False, columns=['Species','Weight(Grams)'])
